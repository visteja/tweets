# %% [markdown]
# <a href="https://colab.research.google.com/github/visteja/tweets/blob/main/tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
encoding = 'latin1'
# Read the CSV file
df = pd.read_csv("demonetization-tweets.csv" ,encoding=encoding)

# Display the first few rows of the dataframe
df.head()
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  5  RT @satishacharya: Reddy Wedding! @mail_today ...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2016-11-23 18:40:30      False
# 1      False              0       NaN  2016-11-23 18:40:29      False
# 2      False              0       NaN  2016-11-23 18:40:03      False
# 3      False              0       NaN  2016-11-23 18:39:59      False
# 4      False              0       NaN  2016-11-23 18:39:39      False
#
#    replyToSID            id  replyToUID  \
# 0         NaN  8.014957e+17         NaN
# 1         NaN  8.014957e+17         NaN
# ...

# %%
#cleaning the data, remove punctuations, remove stopwords, word cloud, Sentiment classification, sentiment score,  Emotion Classification
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
from wordcloud import WordCloud
from textblob import TextBlob

# %%
# Remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

df['clean_text'] = df['text'].apply(remove_punctuation)

# %%
df.head(5)
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  5  RT @satishacharya: Reddy Wedding! @mail_today ...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2016-11-23 18:40:30      False
# 1      False              0       NaN  2016-11-23 18:40:29      False
# 2      False              0       NaN  2016-11-23 18:40:03      False
# 3      False              0       NaN  2016-11-23 18:39:59      False
# 4      False              0       NaN  2016-11-23 18:39:39      False
#
#    replyToSID            id  replyToUID  \
# 0         NaN  8.014957e+17         NaN
# 1         NaN  8.014957e+17         NaN
# ...

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Tokenization
df['tokens'] = df['clean_text'].apply(word_tokenize)

# %%
# Remove stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def remove_stopwords(tokens):
    return [word for word in tokens if word.lower() not in stop_words]

df['clean_tokens'] = df['tokens'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Lemmatization
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

def lemmatize(tokens):
    return [lemmatizer.lemmatize(word) for word in tokens]

df['clean_tokens'] = df['clean_tokens'].apply(lemmatize)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# Join the tokens into a single string
all_words = ' '.join(df['clean_text'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_words)

# %%
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

df['sentiment'] = df['clean_text'].apply(get_sentiment)

# %%
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

df['sentiment'] = df['clean_text'].apply(get_sentiment)

# %%
df['sentiment_score'] = df['clean_text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

def get_emotion(text):
    sentiment_scores = sid.polarity_scores(text)
    if sentiment_scores['compound'] >= 0.05:
        return 'positive'
    elif sentiment_scores['compound'] <= -0.05:
        return 'negative'
    else:
        return 'neutral'

df['emotion'] = df['clean_text'].apply(get_emotion)

# %%
# !pip install nltk
# !python -m nltk.downloader vader_lexicon
# Out:
# ...
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# Count the number of positive and negative tweets
sentiment_counts = df['sentiment'].value_counts()

# Print the counts
print(sentiment_counts)
# Out:
# sentiment
# neutral     6792
# positive    5955
# negative    2193
# Name: count, dtype: int64

# %%
# Plot the word cloud
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
